# %% [markdown]
# ## Open World - binary classification

# %%
import pandas as pd

open_binary = pd.read_csv('drive/MyDrive/test/open_binary.csv')
open_binary.head()
# Out:
#    N_in_packets  N_out_packets  in_first_thirty  out_first_thirty  \
# 0          1300            121               21                 9
# 1           438             80               22                 8
# 2          1240            118               23                 7
# 3          1324            122               21                 9
# 4          1291            115               22                 8
#
#    out_fraction  in_fraction     out_std      in_std    out_mean     in_mean  \
# 0      0.085151     0.914849  398.486335  515.483953  705.106154  774.322314
# 1      0.154440     0.845560  150.591146  139.231951  265.406393  227.162500
# 2      0.086892     0.913108  381.878642  472.735508  669.259677  787.110169
# 3      0.084371     0.915629  406.205288  513.916038  714.503021  821.139344
# 4      0.081792     0.918208  395.028889  503.993490  695.740511  790.608696
#
#    N_packets  time_fraction  sum_N  incoming_packets_size  \
# 0       1421     140.138067   2842                -665600
# 1        518      50.984252   1036                -224256
# 2       1358     122.232223   2716                -634880
# 3       1446     108.233533   2892                -677888
# 4       1406     132.142857   2812                -660992
#
#    outgoing_packets_size  total_packets_size  y
# 0                  61952             -603648  1
# 1                  40960             -183296  1
# 2                  60416             -574464  1
# 3                  62464             -615424  1
# 4                  58880             -602112  1

# %%
print(open_binary.shape)
# Out:
# (29000, 17)

# %%
X = open_binary.drop('y', axis=1)
y = open_binary['y']

print(X.shape)
print(y.shape)
# Out:
# (29000, 16)
# (29000,)

# %%
import numpy as np
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.svm import LinearSVC, SVC
from sklearn.metrics import accuracy_score, recall_score, precision_score

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ## 선형 커널 사용 (SVC)

# %% [markdown]
# ### 튜닝 전 정확도

# %%
svm_linear = SVC(kernel='linear') # C = 1.0
svm_linear.fit(X_train, y_train)
y_pred_linear = svm_linear.predict(X_test)

print('accuracy_score (linear kernel) : ', accuracy_score(y_test, y_pred_linear))
# Out:
# accuracy_score (linear kernel) :  0.7212643678160919

# %%
import matplotlib.pyplot as plt

feature_importance = np.abs(svm_linear.coef_[0])
feature_names = [f"Feature {i+1}" for i in range(len(feature_importance))]

plt.barh(range(len(feature_importance)), feature_importance, align='center')
plt.yticks(range(len(feature_importance)), X.columns)
plt.xlabel('Feature Importance')
plt.title('SVM Feature Importance')
plt.show()

# %%
svm_rbf = SVC(kernel='rbf') # C = 1.0, gamma = scale
svm_rbf.fit(X_train, y_train)
y_pred_rbf = svm_rbf.predict(X_test)

print('accuracy_score (rbf kernel) : ', accuracy_score(y_test, y_pred_rbf))
# Out:
# accuracy_score (rbf kernel) :  0.7579310344827587

# %%
svm_poly = SVC(kernel='poly')
svm_poly.fit(X_train, y_train)
y_pred_poly = svm_poly.predict(X_test)

print('accuracy_score (poly kernel) : ', accuracy_score(y_test, y_pred_poly))
# Out:
# accuracy_score (poly kernel) :  0.7288505747126437

# %% [markdown]
# ### 그리드 서치

# %%
svm = SVC()

# params = {'C': [0.5, 0.6, 0.7, 0.8, 0.9],
#               'kernel': ['linear', 'rbf']}

params = {
    'C': [100, 1000],  # Different values of C
    'kernel': ['rbf'],  # poly는 너무 오래걸리고, linear은 정확도가 너무 낮음..
    'gamma': [0.1, 1, 10],  # gamma=1이 높은 편
}

grid = GridSearchCV(svm, params, refit=True, verbose=3)

# %%
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# [CV 1/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.779 total time=  22.9s
# [CV 2/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.789 total time=  21.1s
# [CV 3/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.785 total time=  20.8s
# [CV 4/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.804 total time=  23.7s
# [CV 5/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.789 total time=  21.6s
# [CV 1/5] END ........C=100, gamma=1, kernel=rbf;, score=0.813 total time=  35.5s
# [CV 2/5] END ........C=100, gamma=1, kernel=rbf;, score=0.816 total time=  36.7s
# [CV 3/5] END ........C=100, gamma=1, kernel=rbf;, score=0.811 total time=  37.6s
# [CV 4/5] END ........C=100, gamma=1, kernel=rbf;, score=0.821 total time=  35.4s
# [CV 5/5] END ........C=100, gamma=1, kernel=rbf;, score=0.815 total time=  34.5s
# [CV 1/5] END .......C=100, gamma=10, kernel=rbf;, score=0.791 total time=  48.8s
# [CV 2/5] END .......C=100, gamma=10, kernel=rbf;, score=0.801 total time=  56.9s
# [CV 3/5] END .......C=100, gamma=10, kernel=rbf;, score=0.787 total time=  50.6s
# [CV 4/5] END .......C=100, gamma=10, kernel=rbf;, score=0.789 total time=  54.5s
# [CV 5/5] END .......C=100, gamma=10, kernel=rbf;, score=0.791 total time=  49.9s
# [CV 1/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.786 total time= 1.6min
# [CV 2/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.796 total time= 1.4min
# [CV 3/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.795 total time= 1.4min
# [CV 4/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.806 total time= 1.6min
# [CV 5/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.797 total time= 1.6min
# [CV 1/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.800 total time= 2.6min
# [CV 2/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.808 total time= 2.6min
# [CV 3/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.804 total time= 2.9min
# [CV 4/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.805 total time= 2.6min
# [CV 5/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.805 total time= 2.8min
# [CV 1/5] END ......C=1000, gamma=10, kernel=rbf;, score=0.784 total time=  52.6s
# [CV 2/5] END ......C=1000, gamma=10, kernel=rbf;, score=0.795 total time= 1.0min
# [CV 3/5] END ......C=1000, gamma=10, kernel=rbf;, score=0.784 total time=  57.3s
# [CV 4/5] END ......C=1000, gamma=10, kernel=rbf;, score=0.782 total time=  59.3s
# [CV 5/5] END ......C=1000, gamma=10, kernel=rbf;, score=0.785 total time=  51.7s
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [100, 1000], 'gamma': [0.1, 1, 10],
#                          'kernel': ['rbf']},
#              verbose=3)

# %%
print("최적 파라미터: ", grid.best_params_)
print("최적 모델: ", grid.best_estimator_)
# Out:
# 최적 파라미터:  {'C': 100, 'gamma': 1, 'kernel': 'rbf'}
# 최적 모델:  SVC(C=100, gamma=1)

# %%
y_pred = grid.best_estimator_.predict(X_test)
print('최적 모델의 교차 검증 정확도: {}'.format(grid.best_score_)) #최적의 하이퍼파라미터 조합에 대한 모델의 예측 정확도 -> 데이터에 대한 모델의 일반화 정도
print("테스트 정확도: {}".format(accuracy_score(y_test, y_pred))) #테스트 데이터셋에 대한 모델의 정확도 -> 이게 낮으면 과적합 위험
# Out:
# 최적 모델의 교차 검증 정확도: 0.8152216748768473
# 테스트 정확도: 0.8124137931034483

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.metrics import precision_score, recall_score
from sklearn.metrics import f1_score, roc_auc_score
import matplotlib.pyplot as plt

def print_graph(y_test, pred=None, pred_proba=None):
    accuracy = accuracy_score(y_test , pred) # 정확도
    precision = precision_score(y_test , pred, average='macro') # 정밀도
    recall = recall_score(y_test , pred, average='macro') # 재현도
    f1 = f1_score(y_test,pred, average='macro')
    estimation=['accuracy','precision','recall']
    value=[accuracy, precision, recall]
    plt.bar(estimation, value)
    plt.title('Random Forest')
    plt.show()
    print('정확도: {0:.4f}, 정밀도: {1:.4f}, 재현율: {2:.4f},\
    F1: {3:.4f}'.format(accuracy, precision, recall, f1))

# %%
print_graph(y_test, y_pred)
# Out:
# 정확도: 0.8124, 정밀도: 0.7970, 재현율: 0.7755,    F1: 0.7840
